# %%
import numpy as np
import glob
import statistics
import matplotlib.pyplot as plt
from prettytable import PrettyTable


def print_statistics(lst, title):
    average = statistics.mean(lst)
    minimum = min(lst)
    maximum = max(lst)
    stdev = statistics.stdev(lst)

    print(f" {title } Average:", average)
    print(f" {title } Minimum:", minimum)
    print(f"{title } Maximum:", maximum)
    print(f"{title } Standard Deviation:", stdev)

# %%
# directory = 'exp_100seed_0.03noise'
# directory = 'all_run_0.4'
directory = 'lorex_prelim'
INN_pattern= f'../results/{directory}/*/KOOPMAN_AE_INN/000_pred.npy'

avg_error = []
last_100_error = []
first_100_error = []

matched_directories = glob.glob(INN_pattern)
for dir_path in matched_directories:
    pred_file = np.load(dir_path)
    
    mean_avg_error = np.mean(pred_file.mean(axis=0))
    mean_last_100_error = np.mean(pred_file.mean(axis=0)[-100:])
    mean_first_100_error = np.mean(pred_file.mean(axis=0)[:100])
    
    print (dir_path.split('/')[3], mean_avg_error,mean_last_100_error,mean_first_100_error )
    
    avg_error.append(mean_avg_error)
    last_100_error.append(mean_last_100_error)
    first_100_error.append(mean_first_100_error)
    
    
#     if np.mean(pred_file.mean(axis=0)[-100:]) > 0.2:
#         print (dir_path.split('/')[3],   np.mean(pred_file.mean(axis=0)[-100:])) 
#         break
    avg_error.append(np.mean(pred_file.mean(axis=0)))
    last_100_error.append(np.mean(pred_file.mean(axis=0)[-100:]))
    first_100_error.append( np.mean(pred_file.mean(axis=0)[:100]))

print_statistics(avg_error, "average Error")
print_statistics(last_100_error, "last 100 prediction")
print_statistics(first_100_error, "first 100 prediction")
# Out:
# 636 1.485882 1.5681082 0.9166383
# 29202 1.3148208 1.4476607 0.5780367
# 9608 1.2946568 1.4800564 0.4798993
# 7562 0.6543804 0.5840114 0.42132735
# 2033 0.47494325 0.5880305 0.21748072
#  average Error Average: 1.0449367
#  average Error Minimum: 0.47494325
# average Error Maximum: 1.485882
# average Error Standard Deviation: 0.423492650455804
#  last 100 prediction Average: 1.1335734
#  last 100 prediction Minimum: 0.5840114
# last 100 prediction Maximum: 1.5681082
# last 100 prediction Standard Deviation: 0.47308848455557795
#  first 100 prediction Average: 0.52267647
#  first 100 prediction Minimum: 0.21748072
# first 100 prediction Maximum: 0.9166383
# first 100 prediction Standard Deviation: 0.24199020902180493

# %%
# directory = 'exp_100seed_0.03noise'
# directory = 'all_run_0.4'
directory = 'lorex_prelim'
INN_pattern= f'../results/{directory}/*/RNN/000_pred.npy'

avg_error = []
last_100_error = []
first_100_error = []

matched_directories = glob.glob(INN_pattern)
for dir_path in matched_directories:
    pred_file = np.load(dir_path)
    
    mean_avg_error = np.mean(pred_file.mean(axis=0))
    mean_last_100_error = np.mean(pred_file.mean(axis=0)[-100:])
    mean_first_100_error = np.mean(pred_file.mean(axis=0)[:100])
    
    print (dir_path.split('/')[3], mean_avg_error,mean_last_100_error,mean_first_100_error )
    
    avg_error.append(mean_avg_error)
    last_100_error.append(mean_last_100_error)
    first_100_error.append(mean_first_100_error)
    
    
#     if np.mean(pred_file.mean(axis=0)[-100:]) > 0.2:
#         print (dir_path.split('/')[3],   np.mean(pred_file.mean(axis=0)[-100:])) 
#         break
    avg_error.append(np.mean(pred_file.mean(axis=0)))
    last_100_error.append(np.mean(pred_file.mean(axis=0)[-100:]))
    first_100_error.append( np.mean(pred_file.mean(axis=0)[:100]))

print_statistics(avg_error, "average Error")
print_statistics(last_100_error, "last 100 prediction")
print_statistics(first_100_error, "first 100 prediction")
# Out:
# 636 0.44214737 0.5098859 0.27947825
# 29202 0.3174641 0.3556176 0.11349375
# 9608 0.33094788 0.37976947 0.1666516
# 7562 0.3342735 0.38681516 0.09434793
# 2033 0.34688592 0.4031665 0.1305105
#  average Error Average: 0.35434374
#  average Error Minimum: 0.3174641
# average Error Maximum: 0.44214737
# average Error Standard Deviation: 0.04731780503862695
#  last 100 prediction Average: 0.40705094
#  last 100 prediction Minimum: 0.3556176
# last 100 prediction Maximum: 0.5098859
# last 100 prediction Standard Deviation: 0.05654746648790579
#  first 100 prediction Average: 0.15689641
#  first 100 prediction Minimum: 0.09434793
# first 100 prediction Maximum: 0.27947825
# first 100 prediction Standard Deviation: 0.06930414666468045

# %%
# directory = 'exp_100seed_0.03noise'
directory = 'lorex_prelim_2'
dae_pattern = f'../results/{directory}/*/DAE/000_pred.npy'
koopman_AE_pattern = f'../results/{directory}/*/Koopman_AE/000_pred.npy'
INN_pattern= f'../results/{directory}/*/KOOPMAN_AE_INN/000_pred.npy'
RNN_Patten=f'../results/{directory}/*/RNN/000_pred.npy'

pattern_list= [dae_pattern,koopman_AE_pattern,INN_pattern,RNN_Patten]

# %%
pattern_names = ["DAE", "Koopman AE", "INN", "RNN"]
for index, ind_patter in enumerate(pattern_list):
    avg_error = []
    last_100_error = []
    first_100_error = []

    matched_directories = glob.glob(ind_patter)
    for dir_path in matched_directories:
        pred_file = np.load(dir_path)
        avg_error.append(np.mean(pred_file.mean(axis=0)))
        last_100_error.append(np.mean(pred_file.mean(axis=0)[-100:]))
        first_100_error.append( np.mean(pred_file.mean(axis=0)[:100]))
        if np.mean(pred_file.mean(axis=0)[-100:]) > 0.1:
            print (dir_path.split('/')[3],   np.mean(pred_file.mean(axis=0)[-100:]) )
        
        
    # Sample data
    data = last_100_error

    # Plotting the histogram
    plt.hist(data, bins=80)

    # Adding labels and title
    plt.xlabel(f'{pattern_names[index]} Last 100 predictions MSE')
    plt.ylabel('Frequency')
    plt.title('Histogram')

    plt.xlim(min(data), max(data))

    # Displaying the plot
    plt.show()
# Out:
# 22051 1.9302214
# 9978 2.4520016
# 30602 2.709599
# 15048 1.670121
# 26325 2.0130732
# 7761 0.5308479
# 25751 2.0577059
# 12060 1.8604225
# 3015 1.3353739
# 18244 1.9126549
# 22051 1.7597222
# 9978 1.8947425
# 15048 1.4309126
# 7761 1.7683464
# 25751 1.9992878
# 3015 1.5247918
# 18244 0.6462214
# 22051 1.2594621
# 9978 1.1591008
# 30602 0.6495726
# 15048 1.9406102
# 26325 0.834474
# 7761 0.6726931
# 25751 2.4246192
# 12060 1.7527674
# 3015 0.9309616
# 18244 2.277311
# 22051 0.6761237
# 15048 0.48644197
# 26325 0.5915057
# 7761 0.5555482
# 12060 0.7417778
# 3015 0.5753586
# 18244 0.652743

# %%
pattern_names = ["DAE", "Koopman AE", "INN", "RNN"]
all_data = []  # Collect all data for common x-axis range

fig, axes = plt.subplots(1, 4, figsize=(16, 4))  # Create a 1x4 grid of subplots

for index, ind_patter in enumerate(pattern_list):
    avg_error = []
    last_100_error = []
    first_100_error = []

    matched_directories = glob.glob(ind_patter)
    for dir_path in matched_directories:
        pred_file = np.load(dir_path)
        avg_error.append(np.mean(pred_file.mean(axis=0)))
        last_100_error.append(np.mean(pred_file.mean(axis=0)[-100:]))
        first_100_error.append(np.mean(pred_file.mean(axis=0)[:100]))

    all_data.extend(last_100_error)  # Collect data for common x-axis range

    # Plotting the histogram
    axes[index].hist(last_100_error, bins=80)

    # Adding labels and title
    axes[index].set_xlabel(f'{pattern_names[index]} Last 100 predictions MSE')
    axes[index].set_ylabel('Frequency')
    axes[index].set_title('Histogram')

    axes[index].set_xlim(min(all_data), max(all_data))  # Set common x-axis range

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
pattern_names = ["DAE", "Koopman AE", "INN", "RNN"]
all_data = []  # Collect all data for common x-axis range

fig, axes = plt.subplots(1, 4, figsize=(16, 4))  # Create a 1x4 grid of subplots

for index, ind_patter in enumerate(pattern_list):
    avg_error = []
    last_100_error = []
    first_100_error = []

    matched_directories = glob.glob(ind_patter)
    for dir_path in matched_directories:
        pred_file = np.load(dir_path)
        avg_error.append(np.mean(pred_file.mean(axis=0)))
        last_100_error.append(np.mean(pred_file.mean(axis=0)[-100:]))
        first_100_error.append(np.mean(pred_file.mean(axis=0)[:100]))

    all_data.extend(last_100_error)  # Collect data for common x-axis range

    # Plotting the histogram
    axes[index].hist(last_100_error, bins=80)

    # Adding labels and title
    axes[index].set_xlabel(f'{pattern_names[index]} Last 100 predictions MSE')
    axes[index].set_ylabel('Frequency')
    axes[index].set_title('Histogram')

# Set common x-axis range
x_min = min(all_data)
x_max = max(all_data)
for ax in axes:
    ax.set_xlim(x_min, x_max)

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
avg_error = []
last_100_error = []
first_100_error = []
matched_directories = glob.glob(dae_pattern)
for dir_path in matched_directories:
    pred_file = np.load(dir_path)
    avg_error.append(np.mean(pred_file.mean(axis=0)))
    last_100_error.append(np.mean(pred_file.mean(axis=0)[-100:]))
    first_100_error.append( np.mean(pred_file.mean(axis=0)[:100]))
    
print_statistics(avg_error, "average Error")
print_statistics(last_100_error, "last 100 prediction")
print_statistics(first_100_error, "first 100 prediction")
# Out:
# [0.672, 0.267, 1.692, 0.451]

# %%
print('Average error overarll pred: ', np.mean(pred_file.mean(axis=0)))
print('Average error of last 100 pred: ', np.mean(pred_file.mean(axis=0)[-100:]))
print('Average error of starting 100 pred: ', np.mean(pred_file.mean(axis=0)[:100]))
# Out:
# Average error overarll pred:  1.2001485
# Average error of last 100 pred:  1.9126549
# Average error of starting 100 pred:  0.39165485

# %%
from prettytable import PrettyTable

def print_statistics(lst, title):
    average = round(statistics.mean(lst), 3)
    minimum = round(min(lst), 3)
    maximum = round(max(lst), 3)
    stdev = round(statistics.stdev(lst), 3)

    return [average, minimum, maximum, stdev]

pattern_list = [dae_pattern, koopman_AE_pattern, INN_pattern, RNN_Patten]
pattern_names = ["DAE", "Koopman AE", "INN", "RNN"]  # Update pattern names here

master_avg_error = []
master_last_100_error = []
master_first_100_error = []

for ind_pattern in pattern_list:
    avg_error = []
    last_100_error = []
    first_100_error = []

    matched_directories = glob.glob(ind_pattern)
    for dir_path in matched_directories:
        pred_file = np.load(dir_path)
        avg_error.append(np.mean(pred_file.mean(axis=0)))
        last_100_error.append(np.mean(pred_file.mean(axis=0)[-100:]))
        first_100_error.append(np.mean(pred_file.mean(axis=0)[:100]))
        
    master_avg_error.append(avg_error)
    master_last_100_error.append(last_100_error)
    master_first_100_error.append(first_100_error)

# Calculate statistics
statistics_data = {}
error_types = ["Average Error (DAE, Koopman AE, INN, RNN)", "Last 100 predictions", "First 100 predictions"]
stat_names = ["Average", "Minimum", "Maximum", "Standard Deviation"]

master_error_lists = [master_avg_error, master_last_100_error, master_first_100_error]

for error_type, master_error in zip(error_types, master_error_lists):
    statistics_data[error_type] = {}
    for i, pattern_name in enumerate(pattern_names):
        statistics_data[error_type][pattern_name] = {
            "Average": print_statistics(master_error[i], "average Error")[0],
            "Minimum": print_statistics(master_error[i], "average Error")[1],
            "Maximum": print_statistics(master_error[i], "average Error")[2],
            "Standard Deviation": print_statistics(master_error[i], "average Error")[3]
        }

# Define the table and its column titles
table = PrettyTable()
table.field_names = ["Statistic"] + error_types

# Add rows to the table
for stat in stat_names:
    row = [stat]
    for error_type in error_types:
        values = [statistics_data[error_type][pattern_name][stat] for pattern_name in pattern_names]
        row.append(values)
    table.add_row(row)

# Print the table
print(table)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 45
#      42     statistics_data[error_type] = {}
#      43     for i, pattern_name in enumerate(pattern_names):
#      44         statistics_data[error_type][pattern_name] = {
# ---> 45             "Average": print_statistics(master_error[i], "average Error")[0],
#      46             "Minimum": print_statistics(master_error[i], "average Error")[1],
#      47             "Maximum": print_statistics(master_error[i], "average Error")[2],
#      48             "Standard Deviation": print_statistics(master_error[i], "average Error")[3]
#      49         }
#      51 # Define the table and its column titles
#      52 table = PrettyTable()
#
# Cell In[10], line 7, in print_statistics(lst, title)
#       5 minimum = round(min(lst), 3)
#       6 maximum = round(max(lst), 3)
# ----> 7 stdev = round(statistics.stdev(lst), 3)
#       9 return [average, minimum, maximum, stdev]
#
# File ~/anaconda5/envs/main_a100/lib/python3.10/statistics.py:828, in stdev(data, xbar)
#     817 """Return the square root of the sample variance.
#     818
#     819 See ``variance`` for arguments and other details.
#    (...)
#     823
#     824 """
#     825 # Fixme: Despite the exact sum of squared deviations, some inaccuracy
#     826 # remain because there are two rounding steps.  The first occurs in
#     827 # the _convert() step for variance(), the second occurs in math.sqrt().
# --> 828 var = variance(data, xbar)
#     829 try:
#     830     return var.sqrt()
#
# File ~/anaconda5/envs/main_a100/lib/python3.10/statistics.py:768, in variance(data, xbar)
#     766 if n < 2:
#     767     raise StatisticsError('variance requires at least two data points')
# --> 768 T, ss = _ss(data, xbar)
#     769 return _convert(ss / (n - 1), T)
#
# File ~/anaconda5/envs/main_a100/lib/python3.10/statistics.py:709, in _ss(data, c)
#     707     return (T, total)
#     708 T, total, count = _sum(data)
# --> 709 mean_n, mean_d = (total / count).as_integer_ratio()
#     710 partials = Counter()
#     711 for n, d in map(_exact_ratio, data):
#
# ValueError: cannot convert NaN to integer ratio
