# %%
import numpy as np
import glob
import statistics
import matplotlib.pyplot as plt
from prettytable import PrettyTable
import math


def calculate_stats(lst):
    average = statistics.mean(lst)
    standard_deviation = statistics.stdev(lst)
    return average, standard_deviation


def truncate(number: float, decimal_places: int):
    multiplier = 10.0 ** decimal_places
    return math.floor(number*multiplier) / multiplier if number >= 0 else math.ceil(number*multiplier) / multiplier

# %%
# Out:
# (30, 1000)

# %%
# directory = 'exp_100seed_0.03noise'
# directory = 'pendulum_no_noise'
# directory = 'pendulum_with_noise'
directory = 'pendulum_with__more_noise'

# directory = 'lorex_prelim_2'
dae_pattern = f'../results/{directory}/*/results_det_pendulum_6_noise_08_DAE/000_pred.npy'
koopman_AE_pattern = f'../results/{directory}/*/results_det_pendulum_6_noise_08_Koopman_AE/000_pred.npy'
INN_pattern= f'../results/{directory}/*/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy'
RNN_Patten=f'../results/{directory}/*/results_det_pendulum_6_noise_08_RNN_NEW/000_pred.npy'

pattern_list= [RNN_Patten, dae_pattern,koopman_AE_pattern,INN_pattern,]

pattern_names = ["RNN","KAE","C-KAE","KIA",]

for index, ind_patter in enumerate(pattern_list):
    avg_error = []
    last_100_error = []
    first_100_error = []

    matched_directories = glob.glob(ind_patter)
    for dir_path in matched_directories:
        pred_file = np.load(dir_path)
    #     if np.mean(pred_file.mean(axis=0)[-100:]) < 0.1:
    #         print (dir_path.split('/')[3],   np.mean(pred_file.mean(axis=0)[-100:])) 
    #         break
        avg1, std_dev1  = calculate_stats(pred_file.mean(axis=0))
        avg3, std_dev3  = calculate_stats(pred_file.mean(axis=0)[:100])
        avg2, std_dev2  = calculate_stats(pred_file.mean(axis=0)[-100:])
        
#         print (std_dev1,std_dev3,std_dev2)

        avg1, std_dev1, std_dev3, std_dev2 = truncate(avg1, 3), truncate(std_dev1, 3), truncate(std_dev3, 3), truncate(std_dev2, 3)

#         print (std_dev1,std_dev3,std_dev2)
        latex_line = f"{pattern_names[index]} & 2.4 & - & {avg1:.3f}\pm{std_dev1:.3f} & {avg3:.3f}\pm{std_dev3:.3f} & {avg2:.3f}\pm{std_dev2:.3f} \\\\"
        print(latex_line)
# Out:
# RNN & 2.4 & - & 0.341\pm0.177 & 0.079\pm0.005 & 0.638\pm0.013 \\
# KAE & 2.4 & - & 0.519\pm0.255 & 0.061\pm0.006 & 0.813\pm0.021 \\
# C-KAE & 2.4 & - & 0.690\pm0.411 & 0.066\pm0.005 & 1.359\pm0.034 \\
# KIA & 2.4 & - & 0.232\pm0.128 & 0.077\pm0.003 & 0.468\pm0.066 \\

# %%
RNN & 2.4 & - & 0.010\pm0.004    &  0.005\pm0.003   &  0.018\pm0.003
# Out:
# ['../results/all_run_0.4/25814/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/9841/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/5729/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/22434/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/23623/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/13643/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/26516/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/2280/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/7260/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/32550/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/11888/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/25242/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/23137/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/28676/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/5670/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/29807/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/6453/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/30592/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/18074/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/26678/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/17461/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/16591/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/29629/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/9987/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/505/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/6300/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/22028/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/30258/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/29687/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/19160/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/23729/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/29507/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/12651/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/15971/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/6859/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/12597/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/29952/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/21118/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/15417/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/22789/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/14775/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/3701/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/4872/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/29801/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/19241/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/19474/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/21494/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/17953/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/6643/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy',
#  '../results/all_run_0.4/140/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy']

# %%
# directory = 'exp_100seed_0.03noise'
directory = 'pendulum_no_noise'
dae_pattern = f'../results/{directory}/*/results_det_pendulum_6_noise_08_DAE/000_pred.npy'
koopman_AE_pattern = f'../results/{directory}/*/results_det_pendulum_6_noise_08_Koopman_AE/000_pred.npy'
INN_pattern= f'../results/{directory}/*/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy'
RNN_Patten=f'../results/{directory}/*/results_det_pendulum_6_noise_08_RNN_NEW/000_pred.npy'

pattern_list= [dae_pattern,koopman_AE_pattern,INN_pattern,RNN_Patten]
print

# %%
pattern_names = ["DAE", "Koopman AE", "INN", "RNN"]
for index, ind_patter in enumerate(pattern_list):
    avg_error = []
    last_100_error = []
    first_100_error = []

    matched_directories = glob.glob(ind_patter)
    for dir_path in matched_directories:
        pred_file = np.load(dir_path)
        avg_error.append(np.mean(pred_file.mean(axis=0)))
        last_100_error.append(np.mean(pred_file.mean(axis=0)[-100:]))
        first_100_error.append( np.mean(pred_file.mean(axis=0)[:100]))
        if np.mean(pred_file.mean(axis=0)[-100:]) < 0.1:
            print (dir_path.split('/')[3],   np.mean(pred_file.mean(axis=0)[-100:]) )
        
        
    # Sample data
    data = last_100_error

    # Plotting the histogram
    plt.hist(data, bins=80)

    # Adding labels and title
    plt.xlabel(f'{pattern_names[index]} Last 100 predictions MSE')
    plt.ylabel('Frequency')
    plt.title('Histogram')

    plt.xlim(min(data), max(data))

    # Displaying the plot
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 28
#      25 plt.ylabel('Frequency')
#      26 plt.title('Histogram')
# ---> 28 plt.xlim(min(data), max(data))
#      30 # Displaying the plot
#      31 plt.show()
#
# ValueError: min() arg is an empty sequence

# %%
pattern_names = ["DAE", "Koopman AE", "INN", "RNN"]
all_data = []  # Collect all data for common x-axis range

fig, axes = plt.subplots(1, 4, figsize=(16, 4))  # Create a 1x4 grid of subplots

for index, ind_patter in enumerate(pattern_list):
    avg_error = []
    last_100_error = []
    first_100_error = []

    matched_directories = glob.glob(ind_patter)
    for dir_path in matched_directories:
        pred_file = np.load(dir_path)
        avg_error.append(np.mean(pred_file.mean(axis=0)))
        last_100_error.append(np.mean(pred_file.mean(axis=0)[-100:]))
        first_100_error.append(np.mean(pred_file.mean(axis=0)[:100]))

    all_data.extend(last_100_error)  # Collect data for common x-axis range

    # Plotting the histogram
    axes[index].hist(last_100_error, bins=80)

    # Adding labels and title
    axes[index].set_xlabel(f'{pattern_names[index]} Last 100 predictions MSE')
    axes[index].set_ylabel('Frequency')
    axes[index].set_title('Histogram')

    axes[index].set_xlim(min(all_data), max(all_data))  # Set common x-axis range

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
pattern_names = ["DAE", "Koopman AE", "INN", "RNN"]
all_data = []  # Collect all data for common x-axis range

fig, axes = plt.subplots(1, 4, figsize=(16, 4))  # Create a 1x4 grid of subplots

for index, ind_patter in enumerate(pattern_list):
    avg_error = []
    last_100_error = []
    first_100_error = []

    matched_directories = glob.glob(ind_patter)
    for dir_path in matched_directories:
        pred_file = np.load(dir_path)
        avg_error.append(np.mean(pred_file.mean(axis=0)))
        last_100_error.append(np.mean(pred_file.mean(axis=0)[-100:]))
        first_100_error.append(np.mean(pred_file.mean(axis=0)[:100]))

    all_data.extend(last_100_error)  # Collect data for common x-axis range

    # Plotting the histogram
    axes[index].hist(last_100_error, bins=80)

    # Adding labels and title
    axes[index].set_xlabel(f'{pattern_names[index]} Last 100 predictions MSE')
    axes[index].set_ylabel('Frequency')
    axes[index].set_title('Histogram')

# Set common x-axis range
x_min = min(all_data)
x_max = max(all_data)
for ax in axes:
    ax.set_xlim(x_min, x_max)

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
avg_error = []
last_100_error = []
first_100_error = []
matched_directories = glob.glob(dae_pattern)
for dir_path in matched_directories:
    pred_file = np.load(dir_path)
    avg_error.append(np.mean(pred_file.mean(axis=0)))
    last_100_error.append(np.mean(pred_file.mean(axis=0)[-100:]))
    first_100_error.append( np.mean(pred_file.mean(axis=0)[:100]))
    
print_statistics(avg_error, "average Error")
print_statistics(last_100_error, "last 100 prediction")
print_statistics(first_100_error, "first 100 prediction")
# Out:
#  average Error Average: 0.12978004
#  average Error Minimum: 0.01630619
# average Error Maximum: 0.62094885
# average Error Standard Deviation: 0.1348152207598304
#  last 100 prediction Average: 0.23287681
#  last 100 prediction Minimum: 0.019868929
# last 100 prediction Maximum: 1.0948231
# last 100 prediction Standard Deviation: 0.2261731567741797
#  first 100 prediction Average: 0.021119932
#  first 100 prediction Minimum: 0.013790556
# first 100 prediction Maximum: 0.083563395
# first 100 prediction Standard Deviation: 0.014643686239269201

# %%
print('Average error overarll pred: ', np.mean(pred_file.mean(axis=0)))
print('Average error of last 100 pred: ', np.mean(pred_file.mean(axis=0)[-100:]))
print('Average error of starting 100 pred: ', np.mean(pred_file.mean(axis=0)[:100]))
# Out:
# Average error overarll pred:  0.032564864
# Average error of last 100 pred:  0.058680512
# Average error of starting 100 pred:  0.014595235

# %%
ind_pattern
# Out:
# '../results/pendulum_no_noise.4/*/results_det_pendulum_6_noise_08_RNN_NEW/000_pred.npy'

# %%
from prettytable import PrettyTable

def print_statistics(lst, title):
    average = round(statistics.mean(lst), 3)
#     minimum = round(min(lst), 3)
#     maximum = round(max(lst), 3)
    stdev = round(statistics.stdev(lst), 3)

    return [average, minimum, maximum, stdev]

pattern_list = [dae_pattern, koopman_AE_pattern, INN_pattern, RNN_Patten]
pattern_names = ["DAE", "Koopman AE", "INN", "RNN"]  # Update pattern names here

master_avg_error = []
master_last_100_error = []
master_first_100_error = []

for ind_pattern in pattern_list:
    avg_error = []
    last_100_error = []
    first_100_error = []

    matched_directories = glob.glob(ind_pattern)
    for dir_path in matched_directories:
        pred_file = np.load(dir_path)
        avg_error.append(np.mean(pred_file.mean(axis=0)))
        last_100_error.append(np.mean(pred_file.mean(axis=0)[-100:]))
        first_100_error.append(np.mean(pred_file.mean(axis=0)[:100]))
        
    master_avg_error.append(avg_error)
    master_last_100_error.append(last_100_error)
    master_first_100_error.append(first_100_error)

# Calculate statistics
statistics_data = {}
error_types = ["Average Error (DAE, Koopman AE, INN, RNN)", "Last 100 predictions", "First 100 predictions"]
stat_names = ["Average", "Minimum", "Maximum", "Standard Deviation"]

master_error_lists = [master_avg_error, master_last_100_error, master_first_100_error]

for error_type, master_error in zip(error_types, master_error_lists):
    statistics_data[error_type] = {}
    for i, pattern_name in enumerate(pattern_names):
        statistics_data[error_type][pattern_name] = {
            "Average": print_statistics(master_error[i], "average Error")[0],
            "Minimum": print_statistics(master_error[i], "average Error")[1],
            "Maximum": print_statistics(master_error[i], "average Error")[2],
            "Standard Deviation": print_statistics(master_error[i], "average Error")[3]
        }

# Define the table and its column titles
table = PrettyTable()
table.field_names = ["Statistic"] + error_types

# Add rows to the table
for stat in stat_names:
    row = [stat]
    for error_type in error_types:
        values = [statistics_data[error_type][pattern_name][stat] for pattern_name in pattern_names]
        row.append(values)
    table.add_row(row)

# Print the table
print(table)
# Out:
# ---------------------------------------------------------------------------
# StatisticsError                           Traceback (most recent call last)
# Cell In[13], line 45
#      42     statistics_data[error_type] = {}
#      43     for i, pattern_name in enumerate(pattern_names):
#      44         statistics_data[error_type][pattern_name] = {
# ---> 45             "Average": print_statistics(master_error[i], "average Error")[0],
#      46             "Minimum": print_statistics(master_error[i], "average Error")[1],
#      47             "Maximum": print_statistics(master_error[i], "average Error")[2],
#      48             "Standard Deviation": print_statistics(master_error[i], "average Error")[3]
#      49         }
#      51 # Define the table and its column titles
#      52 table = PrettyTable()
#
# Cell In[13], line 7, in print_statistics(lst, title)
#       4     average = round(statistics.mean(lst), 3)
#       5 #     minimum = round(min(lst), 3)
#       6 #     maximum = round(max(lst), 3)
# ----> 7     stdev = round(statistics.stdev(lst), 3)
#       9     return [average, minimum, maximum, stdev]
#
# File ~/anaconda5/envs/main_a100/lib/python3.10/statistics.py:828, in stdev(data, xbar)
#     817 """Return the square root of the sample variance.
#     818
#     819 See ``variance`` for arguments and other details.
#    (...)
#     823
#     824 """
#     825 # Fixme: Despite the exact sum of squared deviations, some inaccuracy
#     826 # remain because there are two rounding steps.  The first occurs in
#     827 # the _convert() step for variance(), the second occurs in math.sqrt().
# --> 828 var = variance(data, xbar)
#     829 try:
#     830     return var.sqrt()
#
# File ~/anaconda5/envs/main_a100/lib/python3.10/statistics.py:767, in variance(data, xbar)
#     765 n = len(data)
#     766 if n < 2:
# --> 767     raise StatisticsError('variance requires at least two data points')
#     768 T, ss = _ss(data, xbar)
#     769 return _convert(ss / (n - 1), T)
#
# StatisticsError: variance requires at least two data points
