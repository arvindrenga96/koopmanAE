# %%
import numpy as np
import glob
import statistics
import matplotlib.pyplot as plt
from prettytable import PrettyTable


def print_statistics(lst, title):
    average = statistics.mean(lst)
    minimum = min(lst)
    maximum = max(lst)
    stdev = statistics.stdev(lst)

    print(f" {title } Average:", average)
    print(f" {title } Minimum:", minimum)
    print(f"{title } Maximum:", maximum)
    print(f"{title } Standard Deviation:", stdev)

# %%
# Out:
# (30, 1000)

# %%
# directory = 'exp_100seed_0.03noise'
directory = 'all_run_0.4'
# directory = 'lorex_prelim_2'
INN_pattern= f'../results/{directory}/*/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy'

avg_error = []
last_100_error = []
first_100_error = []

matched_directories = glob.glob(INN_pattern)
for dir_path in matched_directories:
    pred_file = np.load(dir_path)
    if np.mean(pred_file.mean(axis=0)[-100:]) < 0.1:
        print (dir_path.split('/')[3],   np.mean(pred_file.mean(axis=0)[-100:])) 
#         break
    avg_error.append(np.mean(pred_file.mean(axis=0)))
    last_100_error.append(np.mean(pred_file.mean(axis=0)[-100:]))
    first_100_error.append( np.mean(pred_file.mean(axis=0)[:100]))

print_statistics(avg_error, "average Error")
print_statistics(last_100_error, "last 100 prediction")
print_statistics(first_100_error, "first 100 prediction")
# Out:
# 25814 0.033769194
# 22434 0.02071768
# 23623 0.057374403
# 13643 0.034366343
# 26516 0.016520852
# 2280 0.02462842
# 7260 0.02410226
# 25242 0.031715926
# 23137 0.018589063
# 5670 0.06573273
# 29807 0.061672103
# 6453 0.022417655
# 30592 0.07749281
# 26678 0.04919037
# 17461 0.05086452
# 29629 0.017192848
# 9987 0.088807315
# 505 0.023371868
# 6300 0.022665689
# 22028 0.05095522
# 19160 0.021001972
# 23729 0.030981338
# 29507 0.016183902
# 12651 0.01638645
# 15971 0.01874305
# 6859 0.023548646
# 29952 0.02842765
# 21118 0.02927538
# 15417 0.015038655
# 22789 0.027121725
# 14775 0.028852316
# 4872 0.016437145
# 29801 0.039860647
# 21494 0.022670029
# 17953 0.024710147
# 6643 0.037538957
# 140 0.0513983
#  average Error Average: 0.08799115
#  average Error Minimum: 0.0149607
# average Error Maximum: 0.7359159
# average Error Standard Deviation: 0.1631531833732384
#  last 100 prediction Average: 0.22137198
#  last 100 prediction Minimum: 0.015038655
# last 100 prediction Maximum: 1.7768254
# last 100 prediction Standard Deviation: 0.4350916788898106
#  first 100 prediction Average: 0.01586353
#  first 100 prediction Minimum: 0.014361843
# first 100 prediction Maximum: 0.02065115
# first 100 prediction Standard Deviation: 0.0012178369210565422

# %%
INN_pattern
# Out:
# '../results/lorex_prelim_2/*/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy'

# %%
# directory = 'exp_100seed_0.03noise'
directory = 'all_run_0.4'
dae_pattern = f'../results/{directory}/*/results_det_pendulum_6_noise_08_DAE/000_pred.npy'
koopman_AE_pattern = f'../results/{directory}/*/results_det_pendulum_6_noise_08_Koopman_AE/000_pred.npy'
INN_pattern= f'../results/{directory}/*/results_det_pendulum_6_noise_08_KOOPMAN_AE_INN/000_pred.npy'
RNN_Patten=f'../results/{directory}/*/results_det_pendulum_6_noise_08_RNN_NEW/000_pred.npy'

pattern_list= [dae_pattern,koopman_AE_pattern,INN_pattern,RNN_Patten]

# %%
pattern_names = ["DAE", "Koopman AE", "INN", "RNN"]
for index, ind_patter in enumerate(pattern_list):
    avg_error = []
    last_100_error = []
    first_100_error = []

    matched_directories = glob.glob(ind_patter)
    for dir_path in matched_directories:
        pred_file = np.load(dir_path)
        avg_error.append(np.mean(pred_file.mean(axis=0)))
        last_100_error.append(np.mean(pred_file.mean(axis=0)[-100:]))
        first_100_error.append( np.mean(pred_file.mean(axis=0)[:100]))
        if np.mean(pred_file.mean(axis=0)[-100:]) < 0.1:
            print (dir_path.split('/')[3],   np.mean(pred_file.mean(axis=0)[-100:]) )
        
        
    # Sample data
    data = last_100_error

    # Plotting the histogram
    plt.hist(data, bins=80)

    # Adding labels and title
    plt.xlabel(f'{pattern_names[index]} Last 100 predictions MSE')
    plt.ylabel('Frequency')
    plt.title('Histogram')

    plt.xlim(min(data), max(data))

    # Displaying the plot
    plt.show()
# Out:
# 9841 0.07694045
# 26516 0.06467407
# 7260 0.09571375
# 5670 0.095332116
# 30258 0.0829418
# 23729 0.07442687
# 21118 0.05220022
# 22789 0.09047676
# 14775 0.08376196
# 6643 0.019868929
# 25814 0.0730648
# 13643 0.07075342
# 2280 0.06778658
# 11888 0.06373924
# 25242 0.020433951
# 5670 0.0947381
# 6453 0.077542804
# 30592 0.080151364
# 26678 0.08438703
# 29629 0.06925328
# 505 0.06879904
# 6300 0.049497604
# 22028 0.039168183
# 30258 0.068612956
# 29687 0.05923808
# 6859 0.07474875
# 12597 0.055952407
# 21118 0.0891349
# 22789 0.072223164
# 19241 0.07667963
# 21494 0.021309156
# 17953 0.09496203
# 140 0.05391954
# 25814 0.033769194
# 22434 0.02071768
# 23623 0.057374403
# 13643 0.034366343
# 26516 0.016520852
# 2280 0.02462842
# 7260 0.02410226
# 25242 0.031715926
# 23137 0.018589063
# 5670 0.06573273
# 29807 0.061672103
# 6453 0.022417655
# 30592 0.07749281
# 26678 0.04919037
# 17461 0.05086452
# 29629 0.017192848
# 9987 0.088807315
# 505 0.023371868
# 6300 0.022665689
# 22028 0.05095522
# 19160 0.021001972
# 23729 0.030981338
# 29507 0.016183902
# 12651 0.01638645
# 15971 0.01874305
# 6859 0.023548646
# 29952 0.02842765
# 21118 0.02927538
# 15417 0.015038655
# 22789 0.027121725
# 14775 0.028852316
# 4872 0.016437145
# 29801 0.039860647
# 21494 0.022670029
# 17953 0.024710147
# 6643 0.037538957
# 140 0.0513983
# 9841 0.050435003
# 5729 0.029962745
# 22434 0.07306409
# 23623 0.09879402
# 13643 0.019688938
# 26516 0.040028043
# 2280 0.05745133
# 7260 0.04594847
# 11888 0.09626086
# 23137 0.047949623
# 28676 0.048934083
# 5670 0.03568053
# 6453 0.047060896
# 30592 0.022950206
# 18074 0.07015132
# 26678 0.027394867
# 17461 0.09378778
# 29629 0.071733624
# 9987 0.07137305
# 6300 0.0813199
# 22028 0.040004283
# 30258 0.020860663
# 29687 0.043152586
# 19160 0.07797597
# 23729 0.04269421
# 29507 0.05252034
# 12651 0.020926112
# 15971 0.07836713
# 29952 0.077231504
# 21118 0.049199346
# 15417 0.021223372
# 22789 0.019439667
# 14775 0.024074815
# 3701 0.05688425
# 4872 0.041181598
# 29801 0.06681726
# 19241 0.037735578
# 19474 0.01684972
# 21494 0.016057737
# 17953 0.020600524
# 6643 0.05381545
# 140 0.082806304

# %%
pattern_names = ["DAE", "Koopman AE", "INN", "RNN"]
all_data = []  # Collect all data for common x-axis range

fig, axes = plt.subplots(1, 4, figsize=(16, 4))  # Create a 1x4 grid of subplots

for index, ind_patter in enumerate(pattern_list):
    avg_error = []
    last_100_error = []
    first_100_error = []

    matched_directories = glob.glob(ind_patter)
    for dir_path in matched_directories:
        pred_file = np.load(dir_path)
        avg_error.append(np.mean(pred_file.mean(axis=0)))
        last_100_error.append(np.mean(pred_file.mean(axis=0)[-100:]))
        first_100_error.append(np.mean(pred_file.mean(axis=0)[:100]))

    all_data.extend(last_100_error)  # Collect data for common x-axis range

    # Plotting the histogram
    axes[index].hist(last_100_error, bins=80)

    # Adding labels and title
    axes[index].set_xlabel(f'{pattern_names[index]} Last 100 predictions MSE')
    axes[index].set_ylabel('Frequency')
    axes[index].set_title('Histogram')

    axes[index].set_xlim(min(all_data), max(all_data))  # Set common x-axis range

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
pattern_names = ["DAE", "Koopman AE", "INN", "RNN"]
all_data = []  # Collect all data for common x-axis range

fig, axes = plt.subplots(1, 4, figsize=(16, 4))  # Create a 1x4 grid of subplots

for index, ind_patter in enumerate(pattern_list):
    avg_error = []
    last_100_error = []
    first_100_error = []

    matched_directories = glob.glob(ind_patter)
    for dir_path in matched_directories:
        pred_file = np.load(dir_path)
        avg_error.append(np.mean(pred_file.mean(axis=0)))
        last_100_error.append(np.mean(pred_file.mean(axis=0)[-100:]))
        first_100_error.append(np.mean(pred_file.mean(axis=0)[:100]))

    all_data.extend(last_100_error)  # Collect data for common x-axis range

    # Plotting the histogram
    axes[index].hist(last_100_error, bins=80)

    # Adding labels and title
    axes[index].set_xlabel(f'{pattern_names[index]} Last 100 predictions MSE')
    axes[index].set_ylabel('Frequency')
    axes[index].set_title('Histogram')

# Set common x-axis range
x_min = min(all_data)
x_max = max(all_data)
for ax in axes:
    ax.set_xlim(x_min, x_max)

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
avg_error = []
last_100_error = []
first_100_error = []
matched_directories = glob.glob(dae_pattern)
for dir_path in matched_directories:
    pred_file = np.load(dir_path)
    avg_error.append(np.mean(pred_file.mean(axis=0)))
    last_100_error.append(np.mean(pred_file.mean(axis=0)[-100:]))
    first_100_error.append( np.mean(pred_file.mean(axis=0)[:100]))
    
print_statistics(avg_error, "average Error")
print_statistics(last_100_error, "last 100 prediction")
print_statistics(first_100_error, "first 100 prediction")
# Out:
#  average Error Average: 0.12978004
#  average Error Minimum: 0.01630619
# average Error Maximum: 0.62094885
# average Error Standard Deviation: 0.1348152207598304
#  last 100 prediction Average: 0.23287681
#  last 100 prediction Minimum: 0.019868929
# last 100 prediction Maximum: 1.0948231
# last 100 prediction Standard Deviation: 0.2261731567741797
#  first 100 prediction Average: 0.021119932
#  first 100 prediction Minimum: 0.013790556
# first 100 prediction Maximum: 0.083563395
# first 100 prediction Standard Deviation: 0.014643686239269201

# %%
print('Average error overarll pred: ', np.mean(pred_file.mean(axis=0)))
print('Average error of last 100 pred: ', np.mean(pred_file.mean(axis=0)[-100:]))
print('Average error of starting 100 pred: ', np.mean(pred_file.mean(axis=0)[:100]))
# Out:
# Average error overarll pred:  0.032564864
# Average error of last 100 pred:  0.058680512
# Average error of starting 100 pred:  0.014595235

# %%
from prettytable import PrettyTable

def print_statistics(lst, title):
    average = round(statistics.mean(lst), 3)
    minimum = round(min(lst), 3)
    maximum = round(max(lst), 3)
    stdev = round(statistics.stdev(lst), 3)

    return [average, minimum, maximum, stdev]

pattern_list = [dae_pattern, koopman_AE_pattern, INN_pattern, RNN_Patten]
pattern_names = ["DAE", "Koopman AE", "INN", "RNN"]  # Update pattern names here

master_avg_error = []
master_last_100_error = []
master_first_100_error = []

for ind_pattern in pattern_list:
    avg_error = []
    last_100_error = []
    first_100_error = []

    matched_directories = glob.glob(ind_pattern)
    for dir_path in matched_directories:
        pred_file = np.load(dir_path)
        avg_error.append(np.mean(pred_file.mean(axis=0)))
        last_100_error.append(np.mean(pred_file.mean(axis=0)[-100:]))
        first_100_error.append(np.mean(pred_file.mean(axis=0)[:100]))
        
    master_avg_error.append(avg_error)
    master_last_100_error.append(last_100_error)
    master_first_100_error.append(first_100_error)

# Calculate statistics
statistics_data = {}
error_types = ["Average Error (DAE, Koopman AE, INN, RNN)", "Last 100 predictions", "First 100 predictions"]
stat_names = ["Average", "Minimum", "Maximum", "Standard Deviation"]

master_error_lists = [master_avg_error, master_last_100_error, master_first_100_error]

for error_type, master_error in zip(error_types, master_error_lists):
    statistics_data[error_type] = {}
    for i, pattern_name in enumerate(pattern_names):
        statistics_data[error_type][pattern_name] = {
            "Average": print_statistics(master_error[i], "average Error")[0],
            "Minimum": print_statistics(master_error[i], "average Error")[1],
            "Maximum": print_statistics(master_error[i], "average Error")[2],
            "Standard Deviation": print_statistics(master_error[i], "average Error")[3]
        }

# Define the table and its column titles
table = PrettyTable()
table.field_names = ["Statistic"] + error_types

# Add rows to the table
for stat in stat_names:
    row = [stat]
    for error_type in error_types:
        values = [statistics_data[error_type][pattern_name][stat] for pattern_name in pattern_names]
        row.append(values)
    table.add_row(row)

# Print the table
print(table)
# Out:
# +--------------------+-------------------------------------------+------------------------------+------------------------------+
# |     Statistic      | Average Error (DAE, Koopman AE, INN, RNN) |     Last 100 predictions     |    First 100 predictions     |
# +--------------------+-------------------------------------------+------------------------------+------------------------------+
# |      Average       |        [0.13, 0.098, 0.088, 0.037]        | [0.233, 0.172, 0.221, 0.064] | [0.021, 0.017, 0.016, 0.016] |
# |      Minimum       |        [0.016, 0.017, 0.015, 0.016]       |  [0.02, 0.02, 0.015, 0.016]  | [0.014, 0.014, 0.014, 0.014] |
# |      Maximum       |        [0.621, 0.884, 0.736, 0.111]       | [1.095, 1.584, 1.777, 0.208] | [0.084, 0.036, 0.021, 0.019] |
# | Standard Deviation |        [0.135, 0.167, 0.163, 0.02]        | [0.226, 0.267, 0.435, 0.041] | [0.015, 0.004, 0.001, 0.001] |
# +--------------------+-------------------------------------------+------------------------------+------------------------------+
